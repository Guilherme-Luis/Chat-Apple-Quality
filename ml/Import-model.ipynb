# %% [markdown]
# # Trabalho Aprendizado de Máquina
# ## Prof. Jaqueline
# ### Hugo Gabriel Silva Mendes, Guilherme Luís Rodrigues Silva e Miguel Angelo Silva

# %%
import joblib
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
X = pd.read_csv("apple_quality_processed.csv", sep=",")
print(X.columns)
X = X.drop(columns=["Unnamed: 0", "Quality"])
# Out:
# Index(['Unnamed: 0', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %%
# carregar o modelo
loaded_model = joblib.load("model_KNN.pkl")

# %%
# fazer a previsão
loaded_model.predict(X)
# Out:
# array([1, 0, 1, ..., 0, 1, 1])
